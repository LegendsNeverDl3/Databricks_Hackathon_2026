# %%
import pandas as pd

# %%
import pandas as pd
df = pd.read_csv("/Volumes/workspace/default/dataset/US_crop_data.csv")

# %%
df

# %%
df2 = pd.read_csv("/Volumes/workspace/default/dataset/RMACountyYieldsReport-399.csv")

# %%
df2.head()

# %%
merged_df = pd.concat([df, df2], ignore_index=True)
display(merged_df)

# %%
len(merged_df)

# %%
# Assuming 'City' column exists in df and you want to append a 'County' column based on city names.
# Example mapping; replace with actual city-county mapping as needed.
city_to_county = {
    'Los Angeles': 'Los Angeles County',
    'Chicago': 'Cook County',
    'Houston': 'Harris County',
    # Add more city-county pairs as needed
}

df['County'] = df['City'].map(city_to_county)
display(df)
